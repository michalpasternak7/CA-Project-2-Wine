# %% [markdown]
# # Epic 1: Understanding the Data
# Before you start loading in the data, it might be a good idea to check how much you really know about wine and its composition.
#
# There are several varieties of wine, however, as per the business, this analysis will be limited to only red and white wine distinction.
#
# Download the dataset from here: https://archive.ics.uci.edu/ml/datasets/wine+quality
#
# There are 3 data files:
#
# - the file named **winequality-red.csv** contains the dataset pertaining to 1599 records of red wine samples
# - the file named **winequality-white.csv** contains the dataset pertaining to 4898 records of white wine samples
# - the file named **winequality.names** consists of detailed information and the data dictionary pertaining to the datasets
#
# The dataset contains physicochemical and sensory variables which require a bit more understanding.
#
# **Fixed acidity**: acids are major wine properties and contribute greatly to the wine’s taste. Usually, the total acidity is divided into two groups: the volatile acids and the nonvolatile or fixed acids. Among the fixed acids that you can find in wines are the following: tartaric, malic, citric, and succinic. This variable is expressed in **g(tartaricacid)/dm3** in the data sets.
#
# **Volatile acidity**: the volatile acidity is basically the process of wine turning into vinegar. In the U.S, the legal limits of Volatile Acidity are 1.2 g/L for red table wine and 1.1 g/L for white table wine. In these data sets, the volatile acidity is expressed in **g(aceticacid)/dm3**.
#
# **Citric acid** is one of the fixed acids that you’ll find in wines. It’s expressed in **g/dm3** in the two data sets.
#
# **Residual sugar** typically refers to the sugar remaining after fermentation stops, or is stopped. It’s expressed in **g/dm3** in the red and white data.
#
# **Chlorides** can be a significant contributor to saltiness in wine. Here, you’ll see that it’s expressed in **g(sodiumchloride)/dm3**.
#
# **Free sulfur dioxide**: the part of the sulfur dioxide that is added to a wine and that is lost into it is said to be bound, while the active part is said to be free. The winemaker will always try to get the highest proportion of free sulfur to bind. This variable is expressed in **mg/dm3** in the data.
#
# **Total sulfur dioxide** is the sum of the bound and the free sulfur dioxide (SO2). Here, it’s expressed in **mg/dm3**. There are legal limits for sulfur levels in wines: in the EU, red wines can only have 160mg/L, while white and rose wines can have about 210mg/L. Sweet wines are allowed to have 400mg/L. For the US, the legal limits are set at 350mg/L, and for Australia, this is 250mg/L.
#
# **Density** is generally used as a measure of the conversion of sugar to alcohol. Here, it’s expressed in **g/cm3**.
#
# **pH** or the potential of hydrogen is a numeric scale to **specify the acidity or basicity** the wine. As you might know, solutions with a pH less than 7 are acidic, while solutions with a pH greater than 7 are basic. With a pH of 7, pure water is neutral. Most wines have a **pH between 2.9 and 3.9** and are therefore acidic.
#
# **Sulfates** are to wine as gluten is to food. You might already know sulfites from the headaches that they can cause. They are a regular part of wine making around the world and are considered necessary. In this case, they are expressed in **g(potassiumsulphate)/dm3**.
#
# **Alcohol**: wine is an alcoholic beverage, and as you know, the percentage of alcohol can vary from wine to wine. It shouldn’t be surprised that this variable is included in the data sets, where it’s expressed in **% vol**.
#
# **Quality**: wine experts graded the wine quality **between 0 (very bad) and 10 (very excellent)**. The eventual number is the mean of at least three evaluations made by those same wine experts. ***Some analysts might combine these levels to Low, Medium & High-Quality wines.***

# %% [markdown]
# # Epic 2: Load the Data
# Use the Pandas [read_csv()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) function to read the data.
#
# The below code tries to read the red wine file into a dataframe called "red-wine"
#
# If you get any error/unusual data format, please check the **sep argument**.
#
# **DO NOT forget to load the necessary libraries.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the data
red_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
white_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=';')

# %% [markdown]
# # Epic 3: Data Wrangling
# Now let's start to explore the concepts of Data Wrangling on the provided dataset.
#
# Let's start by assessing the data:
#
# - print the first 10 and the last 10 records (use [head()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html) and [tail()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html#pandas.DataFrame.tail) methods)

# %%
red_wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
red_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white_wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# - chech the info and the shape (use [info()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html) and [shape](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html) methods)

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# - observe if there are missing values (use [isna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html), [isnull()](https://pandas.pydata.org/docs/reference/api/pandas.isnull.html))

# %%
red_wine.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
white_wine.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
red_wine.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
white_wine.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# - check for Descriptive Statistics for both red and white wine datasets (use [describe()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html) method)

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# Let's now group our qualities into 3 categories: low, medium and high quality wines.

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label
# 0      9.4        5           low
# ...

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality quality_label
# 0      8.8        6        medium
# ...

# %% [markdown]
# Now we want to create a third dataset, in which we have both red and white wines together. It might be useful for more complex analysis and plots, and we will use it further on to create our first Machine Learning algorithm that will be able to predict the wine type based on its composition.
#
# The original datasets have been modified to contain one new attribute:
#
# - quality_label: This is a derived attribute from the quality attribute contain three labels - low, medium, and high.
# Wines with a quality score of 3, 4, and 5 are low quality, score of 6 and 7 are medium quality, and score of 8 and 9 are high quality wines.

# %% [markdown]
# # Epic 3: Exploratory Analysis
# Using the red_wine and white_wine datasets,create a table like the one below to compare Descriptive Statistics between red and white wines.

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
# this view seems to make the comparison more comfortable
pd.concat([red_wine.describe(), white_wine.describe()], axis=0, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#                          fixed acidity  volatile acidity  citric acid  \
# Red Wines Stats   count    1599.000000       1599.000000  1599.000000
#                   mean        8.319637          0.527821     0.270976
#                   std         1.741096          0.179060     0.194801
#                   min         4.600000          0.120000     0.000000
#                   25%         7.100000          0.390000     0.090000
#                   50%         7.900000          0.520000     0.260000
#                   75%         9.200000          0.640000     0.420000
#                   max        15.900000          1.580000     1.000000
# White Wines Stats count    4898.000000       4898.000000  4898.000000
#                   mean        6.854788          0.278241     0.334192
#                   std         0.843868          0.100795     0.121020
#                   min         3.800000          0.080000     0.000000
# ...

# %% [markdown]
# The code above will produce statistics for all features, however notice that only few columns have been taken into considerations in the image below. So change the code accordingly.

# %%
# create a table only with selected features
features = ['residual sugar', 'total sulfur dioxide', 'sulphates', 'alcohol', 'volatile acidity', 'quality']
pd.concat([red_wine[features].describe(), white_wine[features].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                                 \
#        residual sugar total sulfur dioxide    sulphates      alcohol
# count     1599.000000          1599.000000  1599.000000  1599.000000
# mean         2.538806            46.467792     0.658149    10.422983
# std          1.409928            32.895324     0.169507     1.065668
# min          0.900000             6.000000     0.330000     8.400000
# 25%          1.900000            22.000000     0.550000     9.500000
# 50%          2.200000            38.000000     0.620000    10.200000
# 75%          2.600000            62.000000     0.730000    11.100000
# max         15.500000           289.000000     2.000000    14.900000
#
#                                     White Wines Stats                       \
#       volatile acidity      quality    residual sugar total sulfur dioxide
# count      1599.000000  1599.000000       4898.000000          4898.000000
# ...

# %%
# create a df with all wines for exercises later

# add color of wine as parameter
red_wine['color'] = 'red'
white_wine['color'] = 'white'

# combine the wine dfs
wine = pd.concat([red_wine, white_wine])

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
wine['color'] = pd.Categorical(wine['color'],
categories=['red', 'white'])

# %% [markdown]
# You can observe that the mean value of sulfates and volatile acidity seem to be higher in red wine as compared to white wine.
#
# **Come up with few more observation and write them down in the form of #comment in your VSCode.** This will help you undestand which features is worth investigating further, keeping in mind that we are trying first to understand the difference between red and white wines, and then their respective relations with the quality label.

# %%
#

# %% [markdown]
# ### Let's start plotting!
# Use matplotlib and seaborn to explore relations between features.
#
# The first plot you should do is a [pie chart](https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py), showing the quantity of red wines compared to the quantity of white wines.

# %%
# create a figure and axis
fig1, ax1 = plt.subplots()

# data for the pie chart (based on the amount of entries per wine data set)
data = [red_wine.shape[0], white_wine.shape[0]]

# labels for each section of the pie chart
labels=['Red Wine', 'White Wine']

# colors for each type of wine
colors = ['red', 'lightgreen']

# plot the pie chart (also show % using autopct, add a shadow and explode for aesthetics)
ax1.pie(data, labels=labels,colors=colors, autopct='%1.1f%%', shadow=True, explode=(0.1, 0))

# show the plot
plt.show()

# %% [markdown]
# Now create a plot to show the distribution of qualities. It should look similar to the one below.
#
# Try using the [seaborn histplot](https://seaborn.pydata.org/generated/seaborn.histplot.html).
#
# You have to make sure that both plots have the same order in the X-Axys.
#
# Once you manage to create it, try playing with the colors and the titles too.

# %%
# set the style of seaborn
sns.set(style="whitegrid")

# create a figure with two side-by-side histograms
# the sharey=True parameter ensures that both histograms use the same y-axis scale
fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# plot the first histplot on the left (axes[0])
sns.histplot(data=white_wine, x='quality_label', color='lightgreen', ax=axes[0])
axes[0].set_title('White Wine')
axes[0].set_xlabel('Wine Quality')  # Set the x-axis label

# plot the second histplot on the right (axes[1])
sns.histplot(data=red_wine, x='quality_label', color='red', ax=axes[1])
axes[1].set_title('Red Wine')
axes[1].set_xlabel('Wine Quality')  # Set the x-axis label

# adjust layout is used to adjust the layout so that the plots don't overlap
plt.tight_layout()

# show the plot
plt.show()

# %%
# another way to do the same as above, but using a different notation to get the subplots
# the downside is that in this case, each subplot is independent, and the y-axes may have different scales
# if having a common y-axis is crucial, the plt.subplots method is a better choice (as above)

# set the style of seaborn
sns.set(style="whitegrid")

plt.subplot(121)  # subplot 1 (left)
sns.histplot(data=white_wine, x='quality_label', color='lightgreen')
plt.title('White Wine')
plt.xlabel('Wine Quality')  # set the x-axis label

plt.subplot(122)  # subplot 2 (right)
sns.histplot(data=red_wine, x='quality_label', color='red')
plt.title('Red Wine')
plt.xlabel('Wine Quality')  # set the x-axis label

# adjust layout is used to adjust the layout so that the plots don't overlap
plt.tight_layout()

# show the plot
plt.show()

# %%
'''
The 121 is a shorthand notation for specifying the layout of subplots in a Matplotlib figure. It is in the format of nrows, ncols, and index, where:

- nrows: The total number of rows of subplots.
- ncols: The total number of columns of subplots.
- index: The index of the specific subplot you want to create within the grid.

So, in subplot(121), it means you have one row (nrows=1), two columns (ncols=2), and you are referring to the first subplot (index=1) in this 1x2 grid of subplots.
'''
# Out:
# '\nThe 121 is a shorthand notation for specifying the layout of subplots in a Matplotlib figure. It is in the format of nrows, ncols, and index, where:\n\n- nrows: The total number of rows of subplots.\n- ncols: The total number of columns of subplots.\n- index: The index of the specific subplot you want to create within the grid.\n\nSo, in subplot(121), it means you have one row (nrows=1), two columns (ncols=2), and you are referring to the first subplot (index=1) in this 1x2 grid of subplots.\n'

# %% [markdown]
# Now try to compare the quality with some other features. For example, try reproducing the following box plot.

# %%
# set the style of seaborn
sns.set(style="whitegrid")

# create a figure with two side-by-side boxplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# plot the first boxplot on the left (axes[0])
sns.boxplot(x='quality_label', y='alcohol', data=wine, palette='muted', ax=axes[0])

# plot the second boxplot on the right (axes[1])
sns.boxplot(x='quality_label', y='pH', data=wine, palette='muted', ax=axes[1])

# set labels for the x-axis and y-axis of the first boxplot
axes[0].set(xlabel='Wine Quality Class', ylabel='Wine Alcohol %')

# set labels for the x-axis and y-axis of the second boxplot
axes[1].set(xlabel='Wine Quality Class', ylabel='Wine pH')

# add an overall title to the entire figure
plt.suptitle('Wine Quality - Alcohol Content/pH')

# show the plot
plt.show()
# Out:
# /var/folders/n3/spvzfspj1gn51bldz75lhrt40000gn/T/ipykernel_2100/3998656069.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality_label', y='alcohol', data=wine, palette='muted', ax=axes[0])
# /var/folders/n3/spvzfspj1gn51bldz75lhrt40000gn/T/ipykernel_2100/3998656069.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality_label', y='pH', data=wine, palette='muted', ax=axes[1])

# %%
# another way to do the same as above, but using a different notation to get the subplots

# set the style of seaborn
sns.set(style="whitegrid")

# set the size of the entire plot
plt.figure(figsize=(12, 6))

# plot the first histplot on the left (1)
plt.subplot(121)
sns.boxplot(x='quality_label', y='alcohol', data=wine, palette='muted')

# set labels for the x-axis and y-axis of the first histplot
plt.xlabel('Wine Quality Class')
plt.ylabel('Wine Alcohol %')

# plot the second histplot on the right (2)
plt.subplot(122)
sns.boxplot(x='quality_label', y='pH', data=wine, palette='muted')

# set labels for the x-axis and y-axis of the second histplot
plt.xlabel('Wine Quality Class')
plt.ylabel('Wine pH')

# add an overall title to the entire figure
plt.suptitle('Wine Quality - Alcohol Content/pH')

# show the plot
plt.show()
# Out:
# /var/folders/n3/spvzfspj1gn51bldz75lhrt40000gn/T/ipykernel_2100/3507352399.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality_label', y='alcohol', data=wine, palette='muted')
# /var/folders/n3/spvzfspj1gn51bldz75lhrt40000gn/T/ipykernel_2100/3507352399.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality_label', y='pH', data=wine, palette='muted')

# %% [markdown]
# **Come up with at least 3 more charts with explanations.**

# %% [markdown]
# ### 1. Heatmap of the Correlation Matrix for Wine

# %%
def generate_corr_matrix(wine_df : pd.DataFrame):

    # select columns that can be used for correlation matrix
    # describe() will give us all columns with numeric values and keys() the name of those columns
    numeric_values = list(wine_df.describe().keys())

    # calculate the correlation matrix
    wine_corr = wine_df[numeric_values].corr()

    return wine_corr

wine_corr = generate_corr_matrix(wine)

# now it's still a bit hard to read
wine_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# let's make the data more readable, by adding some color putting it in a heatmap

def create_heatmap(wine_corr, title):

    # create a heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(wine_corr, annot=True, cmap='RdBu_r', fmt=".2f", linewidth=.5)

    # set plot title
    plt.title(title)

    # show the plot
    plt.show()

create_heatmap(wine_corr, 'Wine Correlation Matrix')

# %%
# let's make the data even more readable, by showing only high values
'''
def create_high_value_heatmap(wine_corr, title):
    # function to create high-value correlation heatmap

    # filter for values that have an absolute value of at least .4
    filtered_wine_corr = wine_corr[abs(wine_corr) >= .4]

    # create a heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(filtered_wine_corr, annot=True, cmap='RdBu_r', fmt=".2f", linewidth=.5)

    # set plot title
    plt.title(title)

    # show the plot
    return plt

create_high_value_heatmap(wine_corr, 'Wine Correlation Matrix')
'''
# Out:
# '\ndef create_high_value_heatmap(wine_corr, title):\n    # function to create high-value correlation heatmap\n\n    # filter for values that have an absolute value of at least .4\n    filtered_wine_corr = wine_corr[abs(wine_corr) >= .4]\n\n    # create a heatmap\n    plt.figure(figsize=(10, 8))\n    sns.heatmap(filtered_wine_corr, annot=True, cmap=\'RdBu_r\', fmt=".2f", linewidth=.5)\n\n    # set plot title\n    plt.title(title)\n\n    # show the plot\n    return plt\n\ncreate_high_value_heatmap(wine_corr, \'Wine Correlation Matrix\')\n'

# %%
# let's make the data even more readable, by showing only high values

def create_high_value_heatmap(wine_corr, filter_threshold, title, ax=1, cbar_ax=None):
    # function to create high-value correlation heatmap

    # filter for values that have an absolute value of at least .4
    filtered_wine_corr = wine_corr[abs(wine_corr) >= filter_threshold]

    # create a heatmap
    sns.heatmap(filtered_wine_corr, annot=True, cmap='RdBu_r', fmt=".2f", linewidth=.5, ax=ax, cbar_ax=cbar_ax)

    # set plot title
    ax.set_title(title)

# set style
sns.set(style="white")

# Create a single figure with one subplot
fig, ax = plt.subplots(figsize=(10, 8))

# Create a heatmap for wine correlations in the subplot
create_high_value_heatmap(wine_corr, .4, 'Wine - High Value Correlation Heatmap', ax)

# show the plot
plt.show()

# %%
# let's also print them out as a list

def filter_corr_list(wine_corr, filter_threshold):

    # filter for values that have an absolute value of at least .4
    filtered_wine_corr = wine_corr[(abs(wine_corr) >= filter_threshold) & (wine_corr != 1)]

    # unstack, sort values in descending order, drop duplicates
    filtered_wine_corr = filtered_wine_corr.unstack().sort_values(ascending = False).drop_duplicates()

    # drop NaN values
    filtered_wine_corr = filtered_wine_corr.dropna()

    return filtered_wine_corr

filter_corr_list(wine_corr, .4)
# Out:
# free sulfur dioxide  total sulfur dioxide    0.720934
# residual sugar       density                 0.552517
#                      total sulfur dioxide    0.495482
# fixed acidity        density                 0.458910
# alcohol              quality                 0.444319
# residual sugar       free sulfur dioxide     0.402871
# volatile acidity     total sulfur dioxide   -0.414476
# density              alcohol                -0.686745
# dtype: float64

# %% [markdown]
# Now let's try to do the same for red wine and white wine separately
#
# ### Red:

# %%
red_wine_corr = generate_corr_matrix(red_wine)

# %%
create_heatmap(red_wine_corr, 'Red Wine Correlation Matrix')

# %%
# set style
sns.set(style="white")

# create a single figure with one subplot
fig, ax = plt.subplots(figsize=(10, 8))

# create a heatmap for wine correlations in the subplot
create_high_value_heatmap(red_wine_corr, .4, 'Red Wine Correlation Matrix', ax)

# show the plot
plt.show()

# %%
filter_corr_list(red_wine_corr, .4)
# Out:
# fixed acidity        citric acid             0.671703
#                      density                 0.668047
# free sulfur dioxide  total sulfur dioxide    0.667666
# alcohol              quality                 0.476166
# density              alcohol                -0.496180
# citric acid          pH                     -0.541904
# volatile acidity     citric acid            -0.552496
# fixed acidity        pH                     -0.682978
# dtype: float64

# %% [markdown]
# ### White:

# %%
white_wine_corr = generate_corr_matrix(white_wine)

# %%
create_heatmap(white_wine_corr, 'White Wine Correlation Matrix')

# %%
# set style
sns.set(style="white")

# create a single figure with one subplot
fig, ax = plt.subplots(figsize=(10, 8))

# create a heatmap for wine correlations in the subplot
create_high_value_heatmap(white_wine_corr, .4, 'White Wine Correlation Matrix', ax)

# show the plot
plt.show()

# %%
filter_corr_list(white_wine_corr, .4)
# Out:
# density               residual sugar          0.838966
# free sulfur dioxide   total sulfur dioxide    0.615501
# total sulfur dioxide  density                 0.529881
# alcohol               quality                 0.435575
# residual sugar        total sulfur dioxide    0.401439
# pH                    fixed acidity          -0.425858
# total sulfur dioxide  alcohol                -0.448892
# alcohol               residual sugar         -0.450631
# density               alcohol                -0.780138
# dtype: float64

# %% [markdown]
# Now let's compare the red and white wine heatmaps

# %%
# create a figure with two side-by-side plots
fig, axes = plt.subplots(1, 2, figsize=(22, 10))

# adjust the position of the colorbar
cbar_ax = fig.add_axes([.92, 0.15, 0.02, 0.7])

# plot the first heatmaps
create_high_value_heatmap(red_wine_corr, .4, 'Red Wine Correlation Matrix', axes[0], cbar_ax=cbar_ax)
create_high_value_heatmap(white_wine_corr, .4, 'White Wine Correlation Matrix', axes[1], cbar_ax=cbar_ax)

# show the plot
plt.show()

# %%
# from the heatmaps above we can see, that the correlation between the single properties of the wine is different for red and white wine.
# what does it mean?

# %% [markdown]
# ### 2. Wine Quality and Alcohol Content

# %%
# set the style of seaborn
sns.set(style="whitegrid")

# create a figure with two side-by-side boxplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# boxplot for red wine
sns.boxplot(x='quality_label', y='alcohol', data=red_wine, palette='flare', ax=axes[0]).set(title='Red Wine')

# boxplot for white wine
sns.boxplot(x='quality_label', y='alcohol', data=white_wine, palette='flare', ax=axes[1]).set(title='White Wine')

# set labels for the x-axis and y-axis in both plots
for i in range(len(axes)):
    axes[i].set(xlabel='Wine Quality Class', ylabel='Wine Alcohol %')

# show the plot
plt.show()
# Out:
# /var/folders/n3/spvzfspj1gn51bldz75lhrt40000gn/T/ipykernel_2100/4273679261.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality_label', y='alcohol', data=red_wine, palette='flare', ax=axes[0]).set(title='Red Wine')
# /var/folders/n3/spvzfspj1gn51bldz75lhrt40000gn/T/ipykernel_2100/4273679261.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality_label', y='alcohol', data=white_wine, palette='flare', ax=axes[1]).set(title='White Wine')

# %%
# more alcohol = better wine!

# %% [markdown]
# ### 3. Just have an overall look at plots based on all the single properties of the wine.

# %%
# set the style of seaborn
sns.set(style="whitegrid")

# create a figure with two side-by-side boxplots
fig, axes = plt.subplots(12, 2, figsize=(12, 6 * len(white_wine.describe())), sharey=True)

for i, parameter in enumerate(white_wine.describe().columns):

    sns.histplot(data=red_wine, x=parameter, color='red', ax=axes[i, 0])
    sns.histplot(data=white_wine, x=parameter, color='lightgreen', ax=axes[i, 1])

# show the plot
plt.show()

# %%
for parameter in white_wine.describe().columns:
    # set the style of seaborn
    sns.set(style="whitegrid")

    # create a figure
    fig, ax = plt.subplots()

    # create a custom color palette with red and light green
    custom_palette = sns.color_palette(["red", "lightgreen"])

    ax = sns.histplot(data=wine, x=parameter, hue='color', palette=custom_palette)

    # show the plot
    plt.show()

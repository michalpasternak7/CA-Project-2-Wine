# %% [markdown]
# # Introduction to EDA using Matplotlib and Seaborn

# %%
import numpy as np 
import pandas as pd

# The two libraries for Matplotlib and Seaborn
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Using the movies.csv as the dataset for examples.

movies = pd.read_csv("./movies.csv")

# %%
movies.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
movies.drop([615], axis=0, inplace=True)

# %%
movies.drop(columns=["Summary", "MovieID"], inplace=True)

# %%
movies["Budget"] = movies["Budget"].astype("int")
movies["Gross"] = movies["Gross"].astype("int")
movies["Release Date"] = pd.to_datetime(
    movies["Release Date"], format='%Y-%m-%d', errors='ignore')

# %%
movies.dtypes
# Out:
# Title                   object
# MPAA Rating             object
# Budget                   int64
# Gross                    int64
# Release Date    datetime64[ns]
# Genre                   object
# Runtime                float64
# Rating                 float64
# Rating Count           float64
# dtype: object

# %% [markdown]
# ## Bar chart / countplot

# %% [markdown]
# no histograms -> they are used to show a distribution, which means that the order of the x axis has a meaning. in this case, to show the count of different genres in the dataset, we will use a bar chart or a count plot

# %% [markdown]
# ### Matplotlib

# %%
unique_genres_count = movies["Genre"].value_counts()
plt.figure(figsize=(10, 6)) # Size of the plot

plt.bar(unique_genres_count.index, unique_genres_count, width=0.9, color="darkgreen")

plt.title("This is a matplotlib plot")
plt.xlabel("Genres")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Seaborn

# %%
# sns.barplot(data=movies, x="Genre", y="?")

# %%
plt.figure(figsize=(10, 6))
plt.xticks(rotation=45)
plt.title("This is a seaborn plot")

sns.countplot(x = movies["Genre"], order = movies["Genre"].value_counts().index, color="red")

plt.show()
# Out:
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### Matplotlib

# %%
plt.figure(figsize=(15, 6))
plt.title("This is a matplotlib plot of Gross")
plt.xlabel("Gross")

plt.hist(movies['Gross'], color='lightgreen', bins=40,
         edgecolor='grey', linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.title("This is a matplotlib plot of Budget")
plt.xlabel("Budget")

plt.hist(movies['Budget'], color='lightgreen', bins=80,
         edgecolor='grey', linewidth=0.5)
plt.show()

# %% [markdown]
# Notice how the 2 histogram have different y axis. if we want to have them side by side, we should have a common y axis

# %%
# We create two plots side by side to show the differences or similarities easily. 
# However, it is always best to show a similar Y-Axis when showing two plots side by side. 

fig, axs = plt.subplots(1, 2, sharey="row", tight_layout=True) # sharey = "row" makes the y-axis similar.

axs[0].set_title("Budget")
axs[1].set_title("Gross")

axs[0].hist(movies['Budget'], color='darkgreen', bins=30,
         edgecolor='grey', linewidth=0.5)
axs[1].hist(movies['Gross'], color='lightgreen', bins=30,
         edgecolor='grey', linewidth=0.5)
         
plt.show()

# %% [markdown]
# ## Boxplots

# %% [markdown]
# ### Matplotlib

# %%
genre_budget = {}
for i in movies['Genre'].unique():
    genre_budget[i] = movies[movies['Genre'] == i].Budget
plt.boxplot([x for x in genre_budget.values()],
            labels=[x for x in genre_budget.keys()])
#x and y-axis labels
plt.xlabel('Genre')
plt.ylabel('Budget')
plt.xticks(rotation=45)

#plot title
plt.title('Relation between Genre and Budget using Matplotlib')
# Out:
# Text(0.5, 1.0, 'Relation between Genre and Budget using Matplotlib')

# %% [markdown]
# ### Seaborn

# %%
ax = sns.boxplot(data = movies, y = "Budget", x = "Genre")
ax.tick_params(axis='x', labelrotation=45)

plt.title('Relation between Genre and Budget using Seaborn')
# Out:
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Relation between Genre and Budget using Seaborn')

# %% [markdown]
# # Histplot

# %% [markdown]
# ### Seaborn

# %%
sns.histplot(data=movies, x="Rating",
             color='lightgreen',edgecolor='grey', linewidth=0.5)
# Out:
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(data = movies, x = movies["Budget"],
             color = 'lightgreen', edgecolor = 'grey', linewidth = 0.5, bins = 20)
# Out:
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/michalpasternak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Budget', ylabel='Count'>

# %%
# Basic heat map to show correlation between features. 

plt.figure(figsize=(12,8))

# Find the correlation between variables and store than in a variable which
# will be used to create the heat map.
corr = movies.corr()

sns.heatmap(corr, annot=True, cmap='Spectral')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/michalpasternak/Documents/CA/Project_2/Sprint_1/WB_02 Matplotlib & Seaborn.ipynb Cell 31 line 7
#       <a href='vscode-notebook-cell:/Users/michalpasternak/Documents/CA/Project_2/Sprint_1/WB_02%20Matplotlib%20%26%20Seaborn.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(12,8))
#       <a href='vscode-notebook-cell:/Users/michalpasternak/Documents/CA/Project_2/Sprint_1/WB_02%20Matplotlib%20%26%20Seaborn.ipynb#X42sZmlsZQ%3D%3D?line=4'>5</a> # Find the correlation between variables and store than in a variable which
#       <a href='vscode-notebook-cell:/Users/michalpasternak/Documents/CA/Project_2/Sprint_1/WB_02%20Matplotlib%20%26%20Seaborn.ipynb#X42sZmlsZQ%3D%3D?line=5'>6</a> # will be used to create the heat map.
# ----> <a href='vscode-notebook-cell:/Users/michalpasternak/Documents/CA/Project_2/Sprint_1/WB_02%20Matplotlib%20%26%20Seaborn.ipynb#X42sZmlsZQ%3D%3D?line=6'>7</a> corr = movies.corr()
#       <a href='vscode-notebook-cell:/Users/michalpasternak/Documents/CA/Project_2/Sprint_1/WB_02%20Matplotlib%20%26%20Seaborn.ipynb#X42sZmlsZQ%3D%3D?line=8'>9</a> sns.heatmap(corr, annot=True, cmap='Spectral')
#      <a href='vscode-notebook-cell:/Users/michalpasternak/Documents/CA/Project_2/Sprint_1/WB_02%20Matplotlib%20%26%20Seaborn.ipynb#X42sZmlsZQ%3D%3D?line=10'>11</a> plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: "Look Who's Talking"

# %%
print("The median of Rating: ", movies["Rating"].median())
print("The mean of Rating: ", movies["Rating"].mean())
print("The skew of Rating: ", movies["Rating"].skew())
print("The mode of Rating: ", movies["Rating"].mode())
# Out:
# The median of Rating:  6.9
# The mean of Rating:  6.917322834645669
# The skew of Rating:  -0.29148246606330247
# The mode of Rating:  0    6.9
# Name: Rating, dtype: float64

# %%
print("The median of Budget: ", movies["Budget"].median())
print("The mean of Budget: ", movies["Budget"].mean())
print("The skew of Budget: ", movies["Budget"].skew())
print("The mode of Budget: ", movies["Budget"].mode())
# Out:
# The median of Budget:  80000000.0
# The mean of Budget:  94917098.43577236
# The skew of Budget:  1.01500605044472
# The mode of Budget:  0    150000000
# Name: Budget, dtype: int64
